# %% [markdown]
# **Grid**

# %%
print(' |# ', '============',' ##','============',' ##', '============',' ##','============',' #|')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' |# ', '============',' ##','============',' ##', '============',' ##','============',' #|')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' |# ', '============',' ##','============',' ##', '============',' ##','============',' #|')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' |# ', '============',' ##','============',' ##', '============',' ##','============',' #|')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' ||                ||               ||               ||               || ')
print(' |# ', '============',' ##','============',' ##', '============',' ##','============',' #|')
# Out:
#  |#  ============  ## ============  ## ============  ## ============  #|
#  ||                ||               ||               ||               ||
#  ||                ||               ||               ||               ||
#  ||                ||               ||               ||               ||
#  ||                ||               ||               ||               ||
#  |#  ============  ## ============  ## ============  ## ============  #|
#  ||                ||               ||               ||               ||
#  ||                ||               ||               ||               ||
#  ||                ||               ||               ||               ||
#  ||                ||               ||               ||               ||
#  |#  ============  ## ============  ## ============  ## ============  #|
#  ||                ||               ||               ||               ||
#  ||                ||               ||               ||               ||
# ...

# %% [markdown]
# ****
